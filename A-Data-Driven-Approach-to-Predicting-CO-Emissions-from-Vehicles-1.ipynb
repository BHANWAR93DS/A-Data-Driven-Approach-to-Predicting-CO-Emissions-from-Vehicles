# %%
# Reading the file by uploading
from google.colab import files
uploaded = files.upload()
type(uploaded)
# Out:
#      <input type="file" id="files-08ae7c9d-fd4b-473e-9db0-21d78495c39a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-08ae7c9d-fd4b-473e-9db0-21d78495c39a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("CO2 Emissions_Canada.csv")

# %%
df.head(10)
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT             2.0          4          AS5
# 1  ACURA         ILX       COMPACT             2.4          4           M6
# 2  ACURA  ILX HYBRID       COMPACT             1.5          4          AV7
# 3  ACURA     MDX 4WD   SUV - SMALL             3.5          6          AS6
# 4  ACURA     RDX AWD   SUV - SMALL             3.5          6          AS6
# 5  ACURA         RLX      MID-SIZE             3.5          6          AS6
# 6  ACURA          TL      MID-SIZE             3.5          6          AS6
# 7  ACURA      TL AWD      MID-SIZE             3.7          6          AS6
# 8  ACURA      TL AWD      MID-SIZE             3.7          6           M6
# 9  ACURA         TSX       COMPACT             2.4          4          AS5
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
# ...

# %%
df.head()
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT             2.0          4          AS5
# 1  ACURA         ILX       COMPACT             2.4          4           M6
# 2  ACURA  ILX HYBRID       COMPACT             1.5          4          AV7
# 3  ACURA     MDX 4WD   SUV - SMALL             3.5          6          AS6
# 4  ACURA     RDX AWD   SUV - SMALL             3.5          6          AS6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
# 2         Z                               6.0
# 3         Z                              12.7
# 4         Z                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# ...

# %%
df.describe().T
# Out:
#                                    count        mean        std   min    25%  \
# Engine Size(L)                    7385.0    3.160068   1.354170   0.9    2.0
# Cylinders                         7385.0    5.615030   1.828307   3.0    4.0
# Fuel Consumption City (L/100 km)  7385.0   12.556534   3.500274   4.2   10.1
# Fuel Consumption Hwy (L/100 km)   7385.0    9.041706   2.224456   4.0    7.5
# Fuel Consumption Comb (L/100 km)  7385.0   10.975071   2.892506   4.1    8.9
# Fuel Consumption Comb (mpg)       7385.0   27.481652   7.231879  11.0   22.0
# CO2 Emissions(g/km)               7385.0  250.584699  58.512679  96.0  208.0
#
#                                     50%    75%    max
# Engine Size(L)                      3.0    3.7    8.4
# Cylinders                           6.0    6.0   16.0
# Fuel Consumption City (L/100 km)   12.1   14.6   30.6
# Fuel Consumption Hwy (L/100 km)     8.7   10.2   20.6
# Fuel Consumption Comb (L/100 km)   10.6   12.6   26.1
# ...

# %%
df.isnull().sum()
# Out:
# Make                                0
# Model                               0
# Vehicle Class                       0
# Engine Size(L)                      0
# Cylinders                           0
# Transmission                        0
# Fuel Type                           0
# Fuel Consumption City (L/100 km)    0
# Fuel Consumption Hwy (L/100 km)     0
# Fuel Consumption Comb (L/100 km)    0
# Fuel Consumption Comb (mpg)         0
# CO2 Emissions(g/km)                 0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Vehicle Class', 'Engine Size(L)', 'Cylinders',
#        'Transmission', 'Fuel Type', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7385 entries, 0 to 7384
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Make                              7385 non-null   object
#  1   Model                             7385 non-null   object
#  2   Vehicle Class                     7385 non-null   object
#  3   Engine Size(L)                    7385 non-null   float64
#  4   Cylinders                         7385 non-null   int64
#  5   Transmission                      7385 non-null   object
#  6   Fuel Type                         7385 non-null   object
#  7   Fuel Consumption City (L/100 km)  7385 non-null   float64
#  8   Fuel Consumption Hwy (L/100 km)   7385 non-null   float64
#  9   Fuel Consumption Comb (L/100 km)  7385 non-null   float64
#  10  Fuel Consumption Comb (mpg)       7385 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Vehicle Class', 'Engine Size(L)', 'Cylinders',
#        'Transmission', 'Fuel Type', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)'],
#       dtype='object')

# %%
df_xy = df[['Engine Size(L)', 'Cylinders',
       'Fuel Type', 'Fuel Consumption City (L/100 km)',
       'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
       'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)']]

# %%
df_xy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7385 entries, 0 to 7384
# Data columns (total 8 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Engine Size(L)                    7385 non-null   float64
#  1   Cylinders                         7385 non-null   int64
#  2   Fuel Type                         7385 non-null   object
#  3   Fuel Consumption City (L/100 km)  7385 non-null   float64
#  4   Fuel Consumption Hwy (L/100 km)   7385 non-null   float64
#  5   Fuel Consumption Comb (L/100 km)  7385 non-null   float64
#  6   Fuel Consumption Comb (mpg)       7385 non-null   int64
#  7   CO2 Emissions(g/km)               7385 non-null   int64
# dtypes: float64(4), int64(3), object(1)
# memory usage: 461.7+ KB

# %%
plt.figsize=(6,5)
sns.boxplot(df_xy['CO2 Emissions(g/km)'])
plt.show()

# %%
df_xy['Fuel Type'].value_counts()
# Out:
# Fuel Type
# X    3637
# Z    3202
# E     370
# D     175
# N       1
# Name: count, dtype: int64

# %%
dups=df_xy.duplicated()
print('Number of Duplicated rows = %d'%(dups.sum()))
# Out:
# Number of Duplicated rows = 2958

# %%
df_xy[~df_xy.applymap(np.isreal).all(1)]
# Out:
# /tmp/ipython-input-6497244.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_xy[~df_xy.applymap(np.isreal).all(1)]
#       Engine Size(L)  Cylinders Fuel Type  Fuel Consumption City (L/100 km)  \
# 0                2.0          4         Z                               9.9
# 1                2.4          4         Z                              11.2
# 2                1.5          4         Z                               6.0
# 3                3.5          6         Z                              12.7
# 4                3.5          6         Z                              12.1
# ...              ...        ...       ...                               ...
# 7380             2.0          4         Z                              10.7
# 7381             2.0          4         Z                              11.2
# 7382             2.0          4         Z                              11.7
# ...

# %%
zero_counts = (df_xy == 0).sum()

print(zero_counts)
# Out:
# Engine Size(L)                      0
# Cylinders                           0
# Fuel Type                           0
# Fuel Consumption City (L/100 km)    0
# Fuel Consumption Hwy (L/100 km)     0
# Fuel Consumption Comb (L/100 km)    0
# Fuel Consumption Comb (mpg)         0
# CO2 Emissions(g/km)                 0
# dtype: int64

# %%
df_xy.shape
# Out:
# (7385, 8)

# %%
#remove the duplicate from xy data
df_unique = df_xy.drop_duplicates()

# %%
df_unique.shape
# Out:
# (4427, 8)

# %%
dups1=df_unique.duplicated()
print('Number of Duplicated rows = %d'%(dups1.sum()))
# Out:
# Number of Duplicated rows = 0

# %%
import pandas as pd



df = pd.get_dummies(df_unique, columns=['Fuel Type'], drop_first=True)

print(df.head())
# Out:
#    Engine Size(L)  Cylinders  Fuel Consumption City (L/100 km)  \
# 0             2.0          4                               9.9
# 1             2.4          4                              11.2
# 2             1.5          4                               6.0
# 3             3.5          6                              12.7
# 4             3.5          6                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# 2                              5.8                               5.9
# 3                              9.1                              11.1
# 4                              8.7                              10.6
#
#    Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)  Fuel Type_E  Fuel Type_N  \
# 0                           33                  196        False        False
# ...

# %%
# Identify boolean columns in df
boolean_cols = df.select_dtypes(include='bool').columns


for col in boolean_cols:
    df[col] = df[col].astype(int)

print("DataFrame with boolean columns converted to integers:")
display(df.head())
# Out:
# DataFrame with boolean columns converted to integers:
#    Engine Size(L)  Cylinders  Fuel Consumption City (L/100 km)  \
# 0             2.0          4                               9.9
# 1             2.4          4                              11.2
# 2             1.5          4                               6.0
# 3             3.5          6                              12.7
# 4             3.5          6                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# 2                              5.8                               5.9
# 3                              9.1                              11.1
# 4                              8.7                              10.6
#
#    Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)  Fuel Type_E  Fuel Type_N  \
# ...

# %%
df.head()
# Out:
#    Engine Size(L)  Cylinders  Fuel Consumption City (L/100 km)  \
# 0             2.0          4                               9.9
# 1             2.4          4                              11.2
# 2             1.5          4                               6.0
# 3             3.5          6                              12.7
# 4             3.5          6                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# 2                              5.8                               5.9
# 3                              9.1                              11.1
# 4                              8.7                              10.6
#
#    Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)  Fuel Type_E  Fuel Type_N  \
# 0                           33                  196            0            0
# ...

# %%
def remove_outlier(col):
    sorted(col)
    Q1,Q3=np.percentile(col,[25,75])
    IQR=Q3-Q1
    lower_range= Q1-(1.5*IQR)
    upper_range= Q3+(1.5*IQR)
    return lower_range, upper_range

# %%
for column in df.columns:
    lr,ur= remove_outlier(df[column])
    df[column]=np.where(df[column]>ur,ur,df[column])
    df[column]=np.where(df[column]<lr,lr,df[column])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set a style for better aesthetics
plt.style.use('seaborn-v0_8-whitegrid') # A clean, professional look

plt.figure(figsize=(7, 5)) # Standard widescreen presentation size
sns.boxplot(data=df, orient='v') # Use seaborn boxplot, orient='v' for vertical orientation

plt.title('Distribution of All Variables', fontsize=20, weight='bold') # Larger, bold title
plt.xlabel('Variable', fontsize=16) # Larger x-label
plt.ylabel('Value', fontsize=16) # Larger y-label

plt.xticks(rotation=45, ha='right', fontsize=12) # Rotate and align x-tick labels, larger font
plt.yticks(fontsize=12) # Larger y-tick labels
plt.grid(True, linestyle='--', alpha=0.6) # Add subtle gridlines

plt.tight_layout() # Adjust layout to prevent labels from overlapping

plt.show()

# Save the figure for presentation (high quality)
plt.savefig('distribution_of_variables.png', dpi=300, bbox_inches='tight')

# %%
df.columns
# Out:
# Index(['Engine Size(L)', 'Cylinders', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)', 'Fuel Type_E',
#        'Fuel Type_N', 'Fuel Type_X', 'Fuel Type_Z'],
#       dtype='object')

# %%
df11 = df[['Engine Size(L)', 'Cylinders', 'Fuel Consumption City (L/100 km)',
       'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
       'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)']]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(7, 5))  # Bigger size for PPT clarity
sns.heatmap(df11.corr(),
            annot=True,           # show correlation values
            cmap="Reds",          # warm color palette
            fmt=".2f",            # 2 decimal places
            linewidths=0.5,       # lines between cells
            cbar_kws={'shrink': 0.8, 'label': 'Correlation Strength'})  # color bar

# Add title and adjust font styles
plt.title("Correlation Heatmap of Features", fontsize=18, fontweight='bold', pad=20)
plt.xticks(rotation=45, ha='right', fontsize=11)
plt.yticks(fontsize=11)
plt.tight_layout()

# Optional: export for PPT
plt.savefig("correlation_heatmap_ppt.png", dpi=300, bbox_inches='tight')

plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

# %%
df.columns
# Out:
# Index(['Engine Size(L)', 'Cylinders', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)', 'Fuel Type_E',
#        'Fuel Type_N', 'Fuel Type_X', 'Fuel Type_Z'],
#       dtype='object')

# %%
df.head()
# Out:
#    Engine Size(L)  Cylinders  Fuel Consumption City (L/100 km)  \
# 0             2.0        4.0                               9.9
# 1             2.4        4.0                              11.2
# 2             1.5        4.0                               6.0
# 3             3.5        6.0                              12.7
# 4             3.5        6.0                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# 2                              5.8                               5.9
# 3                              9.1                              11.1
# 4                              8.7                              10.6
#
#    Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)  Fuel Type_E  Fuel Type_N  \
# 0                         33.0                196.0          0.0          0.0
# ...

# %%
X = df[['Engine Size(L)', 'Cylinders', 'Fuel Consumption City (L/100 km)',
       'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
       'Fuel Consumption Comb (mpg)', 'Fuel Type_E',
       'Fuel Type_N', 'Fuel Type_X', 'Fuel Type_Z']]
y = df[ 'CO2 Emissions(g/km)']

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_train_pred = model.predict(X_train)

# %%
mse_train = mean_squared_error(y_train, y_train_pred)
r2_train = r2_score(y_train, y_train_pred)

# %%
print("Training Set Evaluation:")
print("Mean Squared Error (MSE):", mse_train)
print("R-squared (R2) Score:", r2_train)
rmse = np.sqrt(mse_train)
print("RMSE:", rmse)
# Out:
# Training Set Evaluation:
# Mean Squared Error (MSE): 221.76469819236
# R-squared (R2) Score: 0.9339997185876815
# RMSE: 14.891766120657415

# %%
y_test_pred = model.predict(X_test)

# %%
mse_test = mean_squared_error(y_test, y_test_pred)
r2_test = r2_score(y_test, y_test_pred)

# %%
print("\nTest Set Evaluation:")
print("Mean Squared Error (MSE):", mse_test)
print("R-squared (R2) Score:", r2_test)
rmse = np.sqrt(mse_test)
print("RMSE:", rmse)
# Out:
# Test Set Evaluation:
# Mean Squared Error (MSE): 254.72514690418603
# R-squared (R2) Score: 0.9255869509765893
# RMSE: 15.960111118165376

# %%
intercept = model.intercept_

coefficients = model.coef_


print("Intercept:", intercept)
print("Coefficients:", coefficients)
# Out:
# Intercept: 120.55199095644467
# Coefficients: [ 3.27811783e+00  4.43532475e+00 -1.70079071e+00  3.61152729e-01
#   1.30726885e+01 -2.46357388e+00  1.68753900e-14  0.00000000e+00
#   3.98376666e+01  4.07791357e+01]

# %%
X_train.columns
# Out:
# Index(['Engine Size(L)', 'Cylinders', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)', 'Fuel Type_E', 'Fuel Type_N',
#        'Fuel Type_X', 'Fuel Type_Z'],
#       dtype='object')

# %%
intercept = 83.05839481

variables = ['const', 'Engine Size(L)', 'Cylinders',
       'Fuel Consumption City (L/100 km)', 'Fuel Consumption Hwy (L/100 km)',
       'Fuel Consumption Comb (L/100 km)', 'Fuel Consumption Comb (mpg)',
       'Fuel Type_E', 'Fuel Type_N', 'Fuel Type_X', 'Fuel Type_Z']

# Create the linear equation string
linear_equation = f'y = {intercept:.5f}'

for variable, coefficient in zip(variables, coefficients):
    if coefficient >= 0:
        linear_equation += f' + {coefficient:.5f} * {variable}'
    else:
        linear_equation += f' - {-coefficient:.5f} * {variable}'

print(linear_equation)
# Out:
# y = 83.05839 + 3.27812 * const + 4.43532 * Engine Size(L) - 1.70079 * Cylinders + 0.36115 * Fuel Consumption City (L/100 km) + 13.07269 * Fuel Consumption Hwy (L/100 km) - 2.46357 * Fuel Consumption Comb (L/100 km) + 0.00000 * Fuel Consumption Comb (mpg) + 0.00000 * Fuel Type_E + 39.83767 * Fuel Type_N + 40.77914 * Fuel Type_X

# %%
import statsmodels.api as sm

# %%
X_train=sm.add_constant(X_train)
X_test=sm.add_constant(X_test)

# %%
model1=sm.OLS(y_train,X_train).fit()
print(model1.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     CO2 Emissions(g/km)   R-squared:                       0.934
# Model:                             OLS   Adj. R-squared:                  0.934
# Method:                  Least Squares   F-statistic:                     5464.
# Date:                 Wed, 12 Nov 2025   Prob (F-statistic):               0.00
# Time:                         18:54:50   Log-Likelihood:                -12763.
# No. Observations:                 3098   AIC:                         2.554e+04
# Df Residuals:                     3089   BIC:                         2.560e+04
# Df Model:                            8
# Covariance Type:             nonrobust
# ...
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# ...

# %%
X_train=X_train.drop(["Fuel Consumption Hwy (L/100 km)"],axis=1)

# %%
olsmodel_2 = sm.OLS(y_train,X_train)
olsres_2 = olsmodel_2.fit()
print(olsres_2.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     CO2 Emissions(g/km)   R-squared:                       0.934
# Model:                             OLS   Adj. R-squared:                  0.934
# Method:                  Least Squares   F-statistic:                     6247.
# Date:                 Wed, 12 Nov 2025   Prob (F-statistic):               0.00
# Time:                         18:54:50   Log-Likelihood:                -12763.
# No. Observations:                 3098   AIC:                         2.554e+04
# Df Residuals:                     3090   BIC:                         2.559e+04
# Df Model:                            7
# Covariance Type:             nonrobust
# ...
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# ...

# %%
X_train=X_train.drop(["Fuel Type_N"],axis=1)

# %%
olsmodel_3 = sm.OLS(y_train,X_train)
olsres_3 = olsmodel_3.fit()
print(olsres_3.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     CO2 Emissions(g/km)   R-squared:                       0.934
# Model:                             OLS   Adj. R-squared:                  0.934
# Method:                  Least Squares   F-statistic:                     6247.
# Date:                 Wed, 12 Nov 2025   Prob (F-statistic):               0.00
# Time:                         18:54:50   Log-Likelihood:                -12763.
# No. Observations:                 3098   AIC:                         2.554e+04
# Df Residuals:                     3090   BIC:                         2.559e+04
# Df Model:                            7
# Covariance Type:             nonrobust
# ...
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# ...

# %%
X_test.columns
# Out:
# Index(['const', 'Engine Size(L)', 'Cylinders',
#        'Fuel Consumption City (L/100 km)', 'Fuel Consumption Hwy (L/100 km)',
#        'Fuel Consumption Comb (L/100 km)', 'Fuel Consumption Comb (mpg)',
#        'Fuel Type_E', 'Fuel Type_N', 'Fuel Type_X', 'Fuel Type_Z'],
#       dtype='object')

# %%
X_test.head()
# Out:
#       const  Engine Size(L)  Cylinders  Fuel Consumption City (L/100 km)  \
# 5231    1.0             4.0        6.0                              15.8
# 735     1.0             6.0        8.0                              17.9
# 2314    1.0             3.0        6.0                              10.6
# 284     1.0             3.6        6.0                              12.8
# 242     1.0             4.3        6.0                              14.2
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 5231                             11.5                              13.9
# 735                              12.2                              15.3
# 2314                              7.9                               9.4
# 284                               8.6                              10.9
# 242                              10.6                              12.6
#
#       Fuel Consumption Comb (mpg)  Fuel Type_E  Fuel Type_N  Fuel Type_X  \
# ...

# %%
X1_test = X_test[['const', 'Engine Size(L)', 'Cylinders', 'Fuel Consumption City (L/100 km)',
                   'Fuel Consumption Comb (L/100 km)', 'Fuel Consumption Comb (mpg)',
                   'Fuel Type_E', 'Fuel Type_X', 'Fuel Type_Z']]

# %%
olsmod_11 = sm.OLS(y_test,X1_test)
olsres_11 = olsmod_11.fit()
print(olsres_11.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     CO2 Emissions(g/km)   R-squared:                       0.926
# Model:                             OLS   Adj. R-squared:                  0.925
# Method:                  Least Squares   F-statistic:                     2357.
# Date:                 Wed, 12 Nov 2025   Prob (F-statistic):               0.00
# Time:                         18:54:50   Log-Likelihood:                -5564.7
# No. Observations:                 1329   AIC:                         1.115e+04
# Df Residuals:                     1321   BIC:                         1.119e+04
# Df Model:                            7
# Covariance Type:             nonrobust
# ...
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# The primary purpose of this project is to predict CO2 emissions based on various vehicle characteristics and fuel consumption metrics. By building a regression model, we aim to understand which factors most significantly influence CO2 output and to develop a tool that can estimate CO2 emissions for new or different vehicle configurations. This kind of analysis is crucial for environmental assessments, policy making, and for consumers interested in the ecological footprint of vehicles.

# %% [markdown]
# When presenting this project, you should focus on clearly communicating the problem, your approach, key findings, and the implications of your work. Here’s a structure you can follow:
#
# 1. Introduction: Setting the Stage
# Problem Statement: Start by explaining the importance of understanding and predicting CO2 emissions (e.g., environmental impact, policy-making, consumer choices).
# Project Goal: Clearly state that the goal is to predict CO2 emissions based on vehicle characteristics and fuel consumption, and to identify the most influential factors.
# 2. Data Overview & Preprocessing
# Data Source: Briefly mention that you used the CO2 Emissions Canada dataset.
# Key Features: Highlight the types of features available (e.g., Engine Size, Cylinders, Fuel Consumption, Fuel Type).
# Data Cleaning: Explain the steps taken:
# Checking for missing values (and noting none were found).
# Handling duplicate records (identifying and removing them to ensure data integrity).
# Outlier treatment (using the IQR method to cap extreme values).
# Feature Engineering: Explain how 'Fuel Type' (a categorical variable) was converted into numerical form using one-hot encoding.
# 3. Exploratory Data Analysis (EDA) & Insights
# Data Distribution: Mention any key observations from the distributions of variables.
# Correlations: Discuss the correlation heatmap. Point out strong positive or negative correlations between features and 'CO2 Emissions(g/km)'. This helps in understanding which variables are naturally good predictors.
# 4. Methodology: Building the Prediction Model
# Model Choice: State that you used Linear Regression.
# Train-Test Split: Explain that the data was split to evaluate the model's performance on unseen data.
# OLS Regression (Feature Selection): Explain the use of the OLS model to identify statistically significant features. Mention that you dropped variables like 'Fuel Consumption Hwy (L/100 km)' and 'Fuel Type_N' due to their high p-values, simplifying the model while maintaining predictive power.
# 5. Results & Discussion
# Model Performance: Present the key evaluation metrics:
# R-squared (R2): Emphasize the high R2 scores (around 0.93 for training and 0.92 for test), indicating that a large proportion of the variance in CO2 emissions is explained by your model.
# Mean Squared Error (MSE) and Root Mean Squared Error (RMSE): Briefly explain what these mean (average squared difference between predicted and actual, and its square root in the original units) and their relatively low values, suggesting good prediction accuracy.
# Key Drivers of CO2 Emissions: Discuss the coefficients from your final OLS model. Which variables have the largest positive or negative impact on CO2 emissions? (e.g., Engine Size, Cylinders, Fuel Consumption metrics, and different Fuel Types).
# 6. Conclusion & Future Work
# Summary of Findings: Reiterate the main conclusions about what drives CO2 emissions and the model's effectiveness.
# Implications: Discuss how this model can be used (e.g., for environmental policy, vehicle design, consumer guidance).
# Limitations & Future Enhancements: Briefly mention any limitations (e.g., specific dataset, model linearity) and potential areas for future improvement (e.g., exploring other models, more advanced feature engineering, larger datasets).
# Visuals are key! Make sure to include your box plots (before and after outlier treatment), the correlation heatmap, and possibly a plot comparing actual vs. predicted CO2 emissions to visually demonstrate your model's accuracy.
